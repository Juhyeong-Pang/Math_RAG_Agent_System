# %%
import os
import sys
import json
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(os.path.join("..", "..", "data", "math_dataset.csv"))

# %%
df.head()
# Out:
#                                              problem    level  \
# 0           Express $43210_{6}-3210_{7}$ in base 10.  Level 4
# 1  One line is described by\n\[\begin{pmatrix} -1...  Level 3
# 2  Suppose we flip four coins simultaneously: a p...  Level 4
# 3  A game board is constructed by shading two of ...  Level 2
# 4  I have five apples and ten oranges. If a fruit...  Level 5
#
#                      type                                           solution  \
# 0           Number Theory  We convert to base 10 to obtain  \[43210_{6}=4...
# 1             Precalculus  The direction vectors of the lines are $\begin...
# 2              Prealgebra  There are $2^4=16$ possible outcomes, since ea...
# 3              Prealgebra  There are six sections in which the spinner ca...
# 4  Counting & Probability  For a moment, consider empty fruit baskets. No...
#
#                            file_name
# 0            number_theory_1047.json
# 1               precalculus_802.json
# ...
